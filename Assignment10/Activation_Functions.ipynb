# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
def sigmoid(z):
    return 1 / (1 + np.exp(-z))

def relu(z):
    return np.maximum(0, z)

def step(z):
    return np.heaviside(z,0.5)

def leaky_relu(z):
  return np.where(z > 0, z, z * 0.1)

def elu(z):
    return np.where(z > 0, z, 0.1 * (np.exp(z) - 1))

# takes a *numerical* derivative, for our simplicity
def derivative(f, z, eps=0.000001):
    return (f(z + eps) - f(z - eps))/(2 * eps)

z = np.linspace(-5, 5, 200)

plt.figure(figsize=(11,4))

plt.subplot(121)
plt.plot(z, sigmoid(z), "g--", linewidth=2, label="Sigmoid")
plt.plot(z, np.tanh(z), "b-", linewidth=2, label="Tanh")
plt.plot(z, relu(z), "m-.", linewidth=2, label="ReLU")
plt.plot(z, step(z), "y-.", linewidth=2, label="step")
plt.plot(z, leaky_relu(z), "r-.", linewidth=2, label="Leaky relu")
plt.plot(z, elu(z), "c-.", linewidth=2, label="ELU")
plt.grid(True)
plt.legend(loc="center right", fontsize=14)
plt.title("Activation functions", fontsize=14)
plt.axis([-5, 5, -1.2, 1.2])

plt.subplot(122)
plt.plot(z, derivative(np.sign, z), "r-", linewidth=1, label="Step")
plt.plot(0, 0, "ro", markersize=5)
plt.plot(0, 0, "rx", markersize=10)
plt.plot(z, derivative(sigmoid, z), "g--", linewidth=2, label="Sigmoid")
plt.plot(z, derivative(np.tanh, z), "b-", linewidth=2, label="Tanh")
plt.plot(z, derivative(relu, z), "m-.", linewidth=2, label="ReLU")
plt.plot(z, derivative(step,z), "y-.", linewidth=2, label="step")
plt.plot(z, derivative(leaky_relu,z), "r-.", linewidth=2, label="Leaky relu")
plt.plot(z, derivative(elu,z), "c-.", linewidth=2, label="ELU")
plt.grid(True)
#plt.legend(loc="center right", fontsize=14)
plt.title("Derivatives", fontsize=14)
plt.axis([-5, 5, -0.2, 1.2])



plt.show()

# %% [markdown]
# Step is biological accurate, but really bad for mathematical optimization
#
# tanh extreme gradients
#
# sigmoid simular to tanh, less extreme --> Both suffer from very high values, cant determine into which directions to train
#
# elu good gradient properties
#
# Leaky relu for if your network doesnt learn at all
#
# In mode usually ReLU, output with softmax etc.
